# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews_all,reviews

# %%
appnames = [
    'com.black_crypto',
    'com.king.candycrushsaga',
    'com.dts.freefireth',
    'com.instagram.android',
    'com.snapchat.android',
    'com.mxtech.videoplayer.ad',
    'com.flipkart.android',
    'com.pubg.imobile',
    'com.kiloo.subwaysurf',
    'com.ludo.king',
    'org.telegram.messenger',
    'com.phonepe.app',
    'com.truecaller',
    'com.facebook.katana',
    'net.one97.paytm',
    'com.whatsapp',
    'com.adobe.lrmobile',
    'com.supercell.clashofclans',
    'com.activision.callofduty.shooter',
    'com.miniclip.eightballpool',
]

# %%
df_list = []
for app in appnames:
    review = reviews(
        app,
        lang='en', # defaults to 'en'
        country='in', # defaults to 'us'
        sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
        count=1000
    )
    for row in review:
        try:
            for record in row:
                record['app']=app
            df_list.extend(row)
        except Exception as e:
            print(e)
print(len(df_list))
df = pd.DataFrame(df_list)
df.shape
# Out:
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# '_ContinuationToken' object is not iterable
# 19344
# (19344, 11)

# %%
df_list
# Out:
# [{'reviewId': 'gp:AOqpTOFKkjuer-OMthMDUrXGNqzCpIPT9ko1xuuhqDDI76QMymM-MN7mw4UmMF4zIoLcZclMNRCgJ38nLYJ1RUg',
#   'userName': 'Humpty Qadeer',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwHnuGJTcnQby-9tIFO87XnRJ77WcmlbdwwA2v-=mo',
#   'content': 'Awesome app $',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 17, 17, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHIYckh1-I8jbATi2WAiVZBsUFGeqUQW7vmOwVJdrGOa3FF2xL4LkzwNCxERyw1wJxziWb_jcKzkGSgP7U',
#   'userName': 'Danish Ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzdd-VlvKWTvAWUW7CRmzz0jy_UWO6yVBiIfPzh=mo',
#   'content': 'This is a good app+',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 16, 43, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGjPk5PlYJHuUn3fL0oTGedQHzsRaBXTIvoyXVnvHYXmX1xyhSnIVcqBaUIuNACTv75ltpJpADU8mc3DeQ',
#   'userName': 'MS Jamal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwRaS6Vgsh_bXcnORpv_f8u6753ZTsDN-c-EykZ=mo',
#   'content': 'Black Crypto is real good and useful this application we use this application 🌹',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 16, 31, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHguOnxSg9TpdBP0Bgk8ckjJdyiFv0oBb_WTuIGFRz8-YSCgIY6BSBRNNO42bE_VIqxYSq_IVCeA8_hh2U',
#   'userName': 'Muhammad Umer MU9',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwPp4VI2lY5AIPj_Xf4ElNLBWDP0_0O0pK6FXk3=mo',
#   'content': 'Black crypto cloud mining app is awesome really enjoyed having excellent features for online collection of cripto currencies $',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 16, 27, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG3moI2q7lquRfxDs1lEPskRIW6oOggkLJjRepb8RYgW-e-TNLC50JH2ZQWz_QxpjdMMh_CginY3z2Hyds',
#   'userName': 'Alexander23 Valley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJygcPTkwagrqpLNPmxneA8HHMIwRcCb4OeSLW_J=mo',
#   'content': 'Fabulous application .This help me a lotto earn the money.best paltform I recommend to all . Install this application and earn a lot🌻',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 16, 24, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG3Z3G_N7WROgH3aqmaUnwlXeRrx8eVtEsueq67N-qMGV3OWlxPc8IfVN9nJaPtGTKOcUkPLpDW3V83Vo4',
#   'userName': 'Zaigham ZN',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgIBHPVotjbVZYLAo0ykX1Ai4N5bjoKBKq85B5s',
#   'content': 'Great application 🌻',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 16, 10, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGCsw9cJHwi3k97HnjVZ6f7xSQEtwV0Qan7MIL_VMa7D2Go0FNrgKazeqKC9hkcaPyslLDag0g26pBB6Pc',
#   'userName': 'Robert Noah HM',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJymOnBL4RPXeyB_sggl9ucQihY4ogOaB19a_D0=mo',
#   'content': 'Best earning application ever 🥳',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 15, 55, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG0fbxd_Yo9jtTOYvDkzKYQCkaOZahOk6Depp04llZ-BBHB4Qe6ERjCslj-DVqiY0tlUt9Anstpo_9Gzus',
#   'userName': 'My Friend',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxQkArd1HHdlCWZW3FFfFE_LEcQoPyPJxaZh5DN=mo',
#   'content': 'This is a good app 🌻',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 15, 34, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGVSaOEbpvB6HsQXHqAnLMDJ0ZdwStnIhnaBHLMm2qK7t8xTSbO_r4_frD7YjxWyEXZVWlb2dS6rOEqq2Y',
#   'userName': 'Jackie Mp',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxitZRWnnavqNMNl8mxPI0X5r-7K51CTkvTWUYA=mo',
#   'content': 'Black crypto cloud miner is simple superb app I recommend you download this app and use #',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 13, 25, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFSSPLCNgM79MNyoAVIwG8npQJoycKfX2HlS5Y2Npr7zRUzpk9N68CPECpbCT9PBz_jcb2gZT4jKRFwM1k',
#   'userName': 'Deepak Pandey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjCjUk3eVy_hYOU8_wSpOgP6MIwX_e87QSgqiJA',
#   'content': 'App crashes frequently. 4 times in 10 minutes',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 22, 11, 53, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFyWpqvTB5IStE3ecmbYndt210u7Ggx7m3GOaxqy3DCtf2X2LTAytBmezaNWcIXATfcitRmV_NM56YWT9s',
#   'userName': 'Ali Tariq Bloch',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzjIUL7Wc-aHRDQgLrDVTKpohP_oWeoPzJ4Ua5O=mo',
#   'content': 'This is very good and nice app.I like it.🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 9, 33, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGL9MBM8qvFgtwnaAEXOCTdlbfjXZ4OI9WUtENbLx0N9C8SACaMSaXnZiNBV4C_GehWaiTjxXnOHsUhTik',
#   'userName': 'Wise J 22',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhFkpk3I9GeRyedYltGDu4RKbjMqzmaT6RRydQK',
#   'content': 'I registered successfully but they keep telling me to update the app before the mining can start but am unable to update it.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 22, 6, 10, 10),
#   'replyContent': 'Update mean ,you should purchase any of plan accordingly to your balance and then activate start mining',
#   'repliedAt': datetime.datetime(2022, 3, 22, 10, 3, 34),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFLYPDSydfjC6G0kXr0IsmvqSN4ENb2QGK8PSJEl_7rwNoKkAektG0IntwgVOD2W6qGpjg2oY3SGe9s8j0',
#   'userName': 'Anno John',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh2Y67VtF4qP-6gSUb8tidsqWY3XSlX7S_ZMSzt',
#   'content': "Here's my referral code: KOAQUR7",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 22, 3, 32, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHXtd7FiwBtu_5x6gPKg2etcaLh0xTFObBYgF8gtCQZqYBm0AF4x-T4ulwRcZ-zVBr-7R4zQ2evJSmp9bA',
#   'userName': 'Alizbat Alizbat',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzk4Y0G-YEvhLY4Gxt3DXJ4uj_pn8XMU-v7xiGN=mo',
#   'content': 'Black crypto cloud mining is amazing app this app is new and brilliant idea $',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 22, 46, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHDP3y_qW2BL9KdsmYf6w3lKUCCsj_lhhEhhTSFPNwmbBIE-H_0cam6yrcfsgV07VILqZ05-FMwys-q-Es',
#   'userName': 'Peter 05',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx6s77ff6sfIAe5GmEKhGwXigIZTO9PllnNAxAg=mo',
#   'content': 'This app is soo good for crypto mining,, I really like this app 🥳',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 21, 21, 49, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEEbqeL0qrbhx_Ho9qKVKqebQJgRkevuwRfnok14w3M0djM5JO-Xe2KjA1uqoLRajEA0tRAvlB4VIxSoM4',
#   'userName': 'Olva Bruce',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgN1l3g8dwj8KvQXwvoNwyaO5sJ6hgwY-EzIfkT',
#   'content': 'Best mining app....It accurate works .Thanks developer+',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 16, 35, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHg22PDU8AMjoB3TkVbOQYFJZj_MTutuGLiadSUGdIeKZTHFrHdmOWGMTrMpgasDpsEo8dU88xJ1juPdkc',
#   'userName': 'subway 20-20',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhTrAi-meAzpiHEBNnjEhMuG--kNpxT-89crpnXdQ',
#   'content': 'thanks for your response',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 21, 15, 40, 9),
#   'replyContent': 'Go to your purchase section and purchase any of plan accordingly to balance',
#   'repliedAt': datetime.datetime(2022, 3, 21, 15, 37, 28),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHDrCsfc9pEY-yKF5n3w59j3WW92S955zKLlrGxZcF3bQXTq2YRIbV8IHgBE5S2T-SaODlDM2UcNg7gx-4',
#   'userName': 'Sir Warren 1234',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz3EmSZNhfYm9pKPfNFmMhIS5TCdTtagSM_AXWc=mo',
#   'content': 'Black Crypto Cloud Mining is very awesome and incredible application I am so happy to use this application 👍',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 15, 16, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHkhuJ86NTkxqXI4eTKflYcubPRsQmGdN0GRdpL_gwPCtOLt6cOxhVja-z2y-2qnhurMvQ1UMdHmjE56EQ',
#   'userName': 'queen of heart queen of heart',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx_6P6zHBGjlIZ2AVkfPRyyh6z5kGshrsu-wiAL=mo',
#   'content': 'Black crypto is one of the best app in play store. Highly recommended it. Easily to use it. Amazing work and great experience. !!',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 11, 12, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOE3Un7HdnskncPtlOKgfaPtWYhD2Mh6GaTpXuNvQxvQQklslr7MNqx6epQNDr1ASTyb4i2Usl-y4ooOhak',
#   'userName': 'Khalid2 Badshah',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyfIHZSiya4soNrfiaZAhzB82zu7pxbirPml_zX=mo',
#   'content': 'This is very good and interning application. 🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 9, 57, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOF7TEnKuZm5b5nKE2v3jh2NJ57TPjie1VoIhVFuc0q7nZ6BaG-QBm_UkFy-l-AXJhutDF2N5j-HXAixU2k',
#   'userName': 'Ss Ss',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzvDJhhxFa8dCTI4XXrmVeE4MgKey-LajqfbGKw=mo',
#   'content': 'Black crypto app is very best to use it 🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 9, 8, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHUMcMFg65Xl6mbAWNeGsNV1m3I8y6bNcXmnorm7WNE-q-OLnDXdrAshcaTpPGa6wSRseUZXq5_eZlehZE',
#   'userName': 'Andrew Emerson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwo1lBdG5Yqcgpu31n-elZ2R_KCfq3cRPIcyTcw=mo',
#   'content': 'waste',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 21, 3, 59, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG3-pscyVZufAe5Iqs-26unJFd1W1dL4u3kQaNitH0kBrMdxXd_Vk9qc2dpgw_TJz5pLkNOKcFZoqpeuPA',
#   'userName': 'Ayan tufail',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwuoi43RK6nuNwmCLlyKP68b01vovoigLfKy-oU=mo',
#   'content': 'It is best Crypto application we use this application and love this application 🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 23, 16, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHRwD75Pm9ERPw8OIaSO9lBiXKZCx0nfWNObZfOaUBCa5vgRZAXXov_1hO8DhFh9pd7ePZwd_x-13OknZM',
#   'userName': 'Saud Saud',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzECIh_E8kvcUL1e0H_eVL94unWqw7sDZsV00IY=mo',
#   'content': 'Very good application $',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 22, 54, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOE3mm5IOdEyFVTsb0yB1E0Nvs42n47-P9F-b4rccberc9Ech7lgQ3S8QMEYwxepdx6jyuSiW1IrjcSCn74',
#   'userName': 'James Sb',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzlVujf-lCoq4sbnB7IoHovqrLz_bvY_dTPBKC0=mo',
#   'content': 'Very helpful app 🥳',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 21, 12, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHJ8BCmNJvZ5Qn86N_C5vxmflWs037_Bvch6FmiIJQJpai8p-GLDrD9JostIh0ktP-uNERiOrtzoe14Iew',
#   'userName': 'Jooroot Hn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwAVVEIea44L15Kjuh4RYbFabBH9066788KvHqc=mo',
#   'content': 'Very amazing wonderful application👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 20, 55, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGSaiV3EdwYhgngQDX5f2rUzzvAD6VeXGV20q-mms1dJspgwdSqZOK3MTpb4Ms2pQjTRBjs-_alQDLM3sE',
#   'userName': 'Fred Smith',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghs05Q0W82n5iGkdGZFqUCKnrijd_BD2tBb3lds',
#   'content': 'SCAMMERS',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 20, 20, 23, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEyaEFzJzkCf2r0mon0Xkm6-hadMUg78I1TBO_dKn66Tpi-lmkAUq9CZ9ru-_wLGksb6DfplkUmYw3De1M',
#   'userName': 'ANGELINA JOLIE GOOGLE',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwUHhF0C9T4udlHaXGtGyt_3G70DDTKN5aLmKI=mo',
#   'content': 'Black Crypto and Cloud Mining Application is remarkable, glorious and best latest version of the year for use.!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 20, 19, 45, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFVUbRGCiktbyfwhYIFOZQbDHBAMqz5LkGC6sUGnrez1nRrYZNcSQ_SVUIEUIfinBvdY1yaWFZ9imDkJqo',
#   'userName': 'Tariq Lolai',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiLCOXpulemH55pmi2nPd1ZFMFQ2208iMeUvh8B',
#   'content': 'Black crypto mining This is my favorite application and very amazing in it and it works well and unique data is used in it Wonderful Application 👍',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 18, 20, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFTRpIv0isifvDHsHAF9ZzC10pLLFlqqazG7iFaZOvtadDnIUIm740vO60TaNrP_zqJ3uDgWw7BPr_IS-I',
#   'userName': 'Ali Ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxbwAPsLA-VXDa5ZKaTh57Kteu6B2JN14vKPAnk=mo',
#   'content': 'Osm application 🌻',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 15, 45, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHZcaUZ2x73bSvmgP94foTn6EN7tCfbfboGz3Xqhi03ZVR5oF7n8er71sNBmv3xFxSEd9C4V7do9JUdgoA',
#   'userName': 'Misbah Tuk Tuk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjcafLj40EFVP5Evgf7d1iB7HNcah_TEC9TSLgW',
#   'content': 'Black Crypto is very Incredible and fabulous application for the androids users overall controls are very stable and amazing +',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 15, 37, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGsk8VQ__uQVYR99pTpxP-fWJJtpDddk4hZW79mU7BhNRQ64hhUOuXtuvzmhoFptT7twuZUgyfItZY5DtI',
#   'userName': 'arj edgar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GinmAeV2eMDkjmT5zHkAWl54o8ISRUNTNM7r5o3',
#   'content': 'very nice application and cute app 👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 14, 33, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFKJ1DXFvGE06H9JDPSi3_MdyKeCId5-fL-QE7plOgDYVzCmxCmgnvpAcLx4QdF8KIocamxSWyCllaTzX0',
#   'userName': 'Saima sajid234',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwL9Y_mF5S4LGmleZnQwCtENPZHf2OHJn-8Noa8=mo',
#   'content': "Black crypto cloud application.it's application is amazing application.I like that application.🌹",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 14, 14, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEweesRIOxE1w0trdRn4c0JsCR-l3IaXm-aJNAuSbvjP7Vj275PNhb3Zf7WJyFfsKGpoXgqic77EvjitoE',
#   'userName': 'Arnoldo Dk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhGQGWoCCgHrRsgOWM_f4WTUUwg4_1dsZZctCCU',
#   'content': 'Black crypto cloud miner is epic wonderful app I recommend you download this app and use I like it #',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 13, 53, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEo-fri1N9VfW-4PwiHquFwP1dN00UooaE31cti3uAG6DclPtDZtmWkPNkl-IErpdrCktZVXdofscXTHIY',
#   'userName': 'Tasmyia Jameel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyWmm6AY4htRUJ_HNBBtiQ5z3KNj1SKWIWaW02s=mo',
#   'content': 'Black Crypto-Cloud Mining is a best earning app.It is easy in use.I like this app.!!',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 12, 20, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEvcKVC-Vd35Jm1DiKQz-v5ayF-JXualDEmmMKmKV067EGtVkxXf4KucvmWlDmHFiuOdoHMfr-B3qa8_KI',
#   'userName': 'Fish Day',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyMOWntaB3AbA_5x9GA6uXQu-ro5JrbRJR8ev2E=mo',
#   'content': 'Black crypto is a very good and great application!!',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 12, 8, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGlqWVU-n1v3b0TMRb8CUJ03VgVLPWifk9p16XQ_6BlYkgsVui0RdNIh5FsPDc1mAMV0cIfk1zYP0RAv4E',
#   'userName': 'Anierobi Valentine',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggat9nn94qNaEjkOA7API5bTmjSBzgxChd9NqAzBQ',
#   'content': 'I really love it',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 12, 7, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGAoSkKVkD7QGlOVIBsq6id0Q4lfbk0Q6g2s5Fii7ax-oWm5T2PJKavs1w2S6MRdPehKyjBnR_pj9bf4QU',
#   'userName': 'Rana Israr',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxaVjL-1TyvKcyTWDum1YM1zb66DPabyzIOUnOZ=mo',
#   'content': 'Best application🌹',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 11, 14, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHxFT1RQNOyLolBu6_4unqn6Hh0M26WgiUNYxWzEGMwNyWvkAEh4ZzDvtNI2zoFlFIOoBy9IIykxCqEnVY',
#   'userName': 'Sajid Ramzan Bloch',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz0ERscCRBi24mrmRNigBa5ugxiKNjGQ31OkKqc=mo',
#   'content': 'This is very famous and fantastic application.I am use it.🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 11, 4, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFLZdWql5NYuM51IsF7D66b5u320lZk79Eoy6zHehp8hqxthe9Ja7sZacLThzIOiJwcqw4nh5qUnw6g7k4',
#   'userName': 'Tom Lia',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxrNGI17PxX99WdBJQ0VXAmjhMVeOmotmPcC7QX=mo',
#   'content': 'Great application easy to use the service 🌹',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 10, 55, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEQDZsNqccFm3z2o4jqgyu0aQ8t_SFFqbGp3rm56mJVMancqDIQpjDL0UXbvXqL28AFUt8JgTSo6Qasbpg',
#   'userName': 'Milan pickett Qhr',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwFQ8pkT9An-UmNjx9SGRf0Z3m0i2yLPsXXhgA=mo',
#   'content': 'Very amazing and very nice application and very beautiful application my favourite👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 9, 6, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEbOPgie058XQOUh7rWAvH5M6JlQ2-aUTF0ZsjnilSYEs-TEsYXarjBSs2JdHzaiSbuVy_HgDBKYJH-UKs',
#   'userName': 'Parkision DC',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzn12oCmx5p92fNtZKG-FgPiNVrxpwgbXLoN4wM=mo',
#   'content': 'Amazing wonderful application👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 8, 52, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHqSgCKUqIonkZ013w1Z6n4wKYs888zSd6MfuI55qdqGIdu56RJfrL6uTqJqGNnHJBEdPQYsBcictIjsm8',
#   'userName': 'marlin Win',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh4OgtLbgrUepNZmuUK910i1s8qKa1r6h2YywWU',
#   'content': 'this is very good application I like it very much very good and amazing application in the play store👍',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 8, 0, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEylqgZX_kBcTZtB_OJ8Q7yOOSVKF3ap45WO5nxwBx9ZKPTfwiwXSGMBklbi5FaGUSJgfQTT4kju5ftcx0',
#   'userName': 'Lakshmi v',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwU7OrVfet3IG8uBmGuJ1pBIV668AgCmow_sCsh=mo',
#   'content': 'Good app 👍',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 20, 7, 58, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFpD3UGxsI6RlpMI4tz4SzeNFEcitZjqHjnj3lnldxB3I3pz1adjkMU1EmJwiraKpZt2jt_RFfSZWoc67A',
#   'userName': 'Kenzo YT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiPGCX9irJN6a4gxVanrdQKSegeROW6D-UM4oDwrg',
#   'content': 'CODE:KOAQUR7',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 3, 18, 13, 30, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG6xFoBLddM4nLLUfqjdhviSBcMgcCLnO502lHAsuLr7VYIskBXotR15yKYBw61Z_FJHwM3OqbwLZV1rkQ',
#   'userName': 'king',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhEsjeE77dtkMC4m2xGPH3ES_3bJyKQZl8vwBo6Ww',
#   'content': 'It let me get to .1 btc then goes back to zero',
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.7',
#   'at': datetime.datetime(2022, 3, 2, 17, 34, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFrZvZjaOrGzMY2eTZ5wgT6BwVi5RzJJHvklCsK9Ss_KQqedhy-Z5k9z0GKRHJGvmMbfqdoQqYi2bPc33I',
#   'userName': 'ASHU &FACTS',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi6WyzlGnG0h_DNvHUrnfHOwkN_velk_ukNp4ivrw',
#   'content': 'I purchesd this app but its very wrost app becuase when i click start mining the app close automatically and show app crash why i am using 8gb ram andriod device and with snapdragon 836 can some one tell me why this happening with me',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 21, 1, 8, 43),
#   'replyContent': 'We are understand your problem.  We apologize to you. We have send the update to google play about this issue. Many users which have 320dpxi resolution are facing the same issue. Please wait update will be live on google play within 24 hours',
#   'repliedAt': datetime.datetime(2022, 2, 21, 1, 46, 30),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGr0RdoSMp8l0s28ADbOaYVw3_0RpMa4Zg8Rt6-JZLIY221-jiYVIyXSWjbt9AhIwdFG8Zr1Bloxp5N5IY',
#   'userName': 'Mohammad Sumon',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiQ4zYdnHZw7e1ul_46wLk_OiDQ2ww_kxICLJSxaQ',
#   'content': 'After last update,when l start mining it crashes everytime.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 19, 1, 6, 46),
#   'replyContent': 'We understand your problem we have send another update to google play. It will live on on google within 2 days then your problem will be resolved',
#   'repliedAt': datetime.datetime(2022, 2, 19, 2, 49, 2),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFHjUu_78jIoY5xZY2X_0lH7KJFqWegPl60UPQHvy79CY52W7gcuZCrGeB7FEkMIo9CMoJ7G6JwVkUthl0',
#   'userName': 'Aqib Mushtaq',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyM4voT_Ap86_Yywzyltd1px4dHXzgzAE0SXtVk=mo',
#   'content': 'This app wont survive for long term whenever message or phone pops up during mining all the mined data wiped out and not saved which is a bug or intentionally put by developers so that users can only pay for hash rates not earn it seems so. Backgroud mining is different senerio but switching tabs inside app wont save the data is like a scam.',
#   'score': 1,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 18, 7, 29, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGZpLZnTVscgyYPxTPr5eiiUQts9i7dq2ghYK0sOc73aTMunZ6oTckdtTm59_HHM9SQDpLYEdjh118aDLg',
#   'userName': 'waseem jpeter',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiWBRljEsNCvmLX_QfwsabrOxsgnn6kDySzTfHL6Q',
#   'content': "Don't even let me start mining. Keep crashing after I click. Sign up",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 18, 3, 7, 46),
#   'replyContent': 'We have send the update to google play. It will updated with in 2 days.  Please keep patience then your issue will be resolved',
#   'repliedAt': datetime.datetime(2022, 2, 18, 11, 19, 47),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGN522Xn_4VRykSD7iutN4OCw6YSJGZ4NtLic5sloY5lF_HodWqkhCPIgMVz5R7vVtMXx8P2mVqEqx211A',
#   'userName': 'Isaac Miss',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwjwYjaA0D-s29aA4vbum2rAx9CjK7NV3XK8Jk9=mo',
#   'content': 'Black crypto application very useful and very easy to download application🥰',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 21, 23, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG7ZXXFhsolQrrkuPvKD0_Buyr8Kzl37vb9B4MOzKlack2hiibu_XRkm2D2LyerJOucst_kR-Av-rZjpr4',
#   'userName': 'Asdd Asdd pkg',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx6uaGZcdfxxjnaOn80l0IIbpFHn2vaq2fmHj5B=mo',
#   'content': 'Nice app 🥰',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 21, 23, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHKHPAE_3ZsRfI-YN2ytRHSkzhBR0i1WsnZiEDtx08uCViRu72efJtF3vDrz9H7bN2b5TXIm8k34Q18hJY',
#   'userName': 'Hayden By so',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhAiXNv1Bta02Ra7-yl4qRZvmrRhiA6AfMJw5xj',
#   'content': 'Very nice application amazing application good application🙂🙂',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 17, 3, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOExJoEnhLVJR9pGlGwM3N5SOmXfYc3ufe_RvX08LNf_QBn0oa4QVGKkc1YVxKDCefhh3wnCVGKy8zsPhAA',
#   'userName': 'PAKISTAN Army A. M',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GheW0tWjc7xQrXgiuzR5-EuPNP3tPEqzxH2_XNc',
#   'content': 'Black crypto is an outstanding cloud mining application. Easy to install and easy to use. 🤩',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 13, 47, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHLynbyMA0YTSb_w7nST84PulTIp4pARrzPH5-S6hhZGV5YhiOwObH6eOO3bEmgNvyCvjmniwNHhVGTRfw',
#   'userName': 'NewsAlert 143',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyamoYrSht9joTnBdbfPlWG3PHKHmfkTHcKKYWg=mo',
#   'content': 'This application for communication I used it for communication🤩',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 13, 24, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOH-BqQ1FGAsKQ1wtTLOSXYmH7JoGouG0n8dIf2HF-YAJG1_VLwXXAcnlYzIEvCVibpRsfUujPmYHngzdqA',
#   'userName': 'Qamar din',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwPeKwKnEKu0vYPrMUVPn5HC2M26dQQWa-QwCAL=mo',
#   'content': 'Black Crypto application is best application we love this application so superb 🤩',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 12, 19, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEK8jybDixwxcKJAnHiFHK2x2duT-tX5BBiC2XaKXD7JPQNA1VfpT261nsBAv5IwnGJObKvGv7C425ARLM',
#   'userName': 'Amit Barman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh92CDxn9zJDrAAV_cPG32ntNRVJbMYdbeRB7E1',
#   'content': '9.99 $',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 17, 9, 53, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFPIzmvlbsZqSNnLA4IYed_w3JzM7twDtcFdUqduLAKw25tfXyV5qGmfX-HLb2joDIU2iuz1Qcn5_4kHQg',
#   'userName': 'Grace Cerillo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gje4NkuOciAr0XHTqQjpa2JPp54Wc2TGvZqMD4ZdQ',
#   'content': "doesn't even start to mine lol,it closes everytime I start to mine",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 8, 13, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHienI1G9Weoe_oGR6XeDvhQRQUpnvshAXz-fmVzk1kR3gzAGARiXIDRjfndLhp4Hunu-GBcgw4IAyBJuU',
#   'userName': 'Surendra Patel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx4bvRDV9MOLOeLzaU85b7QR-wf8fu5oohY_oKacw=mo',
#   'content': "Don't even download.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 17, 7, 0, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEw6Y0Hg9DRY1ydY6C8zmdaPv0gZT8CazCgIlNgji1PkP94VultWa2eV-8M4cyTwlKb4vwH3poNLb8JI8Y',
#   'userName': 'Stephan Stephan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzyT9c5_TWQ6FANyox7XxqmGzbUXUd_lx4g6eM5=mo',
#   'content': 'Black crypto-cloud mining is very interesting application with simple to use. It is the best source of enjoyment. I like it🙂',
#   'score': 5,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 21, 41, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGXe42fToFWGWYbhS_9IaCwGRHCAH12WTc9KolsZPptr90N6zU2XSBLB4X1L6gClTy7zS1aw-nQZSwBbVk',
#   'userName': 'Coffee king Sm',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzvmwobMP9k_UcIW-Nz9wkq9Gqz90kBtruZ9kwM=mo',
#   'content': 'Very nice very good application🥰',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 18, 57, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFbR1MG-jRgSeD4ekU04qqwQkuQYEJgvsg2YJosFgELTDrBqqnqmOgLIQXbKhcyzp6fWllxbADST0zcB0U',
#   'userName': 'Angela NA',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzurjIMUcC1SfgTQcB7XPmFuGilpHrtkkcZ1Vh_=mo',
#   'content': 'Black crypto Cloud mining app is simple use I like this application . I download this application. 🥰',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 18, 9, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOG6R9jmSizGK2crmaNZb8_omcI6-935zPLrQFKYmAaAaLb_VctGvBCjoNs59pJ_tqZHFasGIvBu2PSS8CY',
#   'userName': 'Michael Goettenauer',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyxSOIM4ttm9VrLAjc0Uf2H0jh6iYCBxDQx1kMd=mo',
#   'content': 'SCAM. It takes 15 years to reach their minimum payout hurdle. SCAM! They should go to prison. All 5 star reviews are obviously bought and fake. Ridiculous app, run away as fast as you can.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 14, 37, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFfYWJwTS68gTvoG-oKiFpTGnDB1yW9YyG4Ix65CBtHKREwcaIfgkRNqw4zo1QssHMctR9XHZQwOUZOnBU',
#   'userName': 'Sb sy pyari nend Mno',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyo0ID36JRLXNyuwGJp-d8wk0SMUdtRme-tIQlM=mo',
#   'content': 'Black crypto cloud is a very fantasting app and I give it 5 star because is the best app.🥰',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 12, 44, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEXT1kMKRtixlqcXhsYG_3jzAKo4a8_CtZQBqv7h7ctCDSP2rcYKIOv6mNQkndK5peNUH6vc1Awu5Jy8gM',
#   'userName': 'Addison Harry',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgxMde29dkAB5FU-jim0B5PSZ4Gmf88toX1ACG-',
#   'content': 'It is very nice I like it very much🥰',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 12, 4, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGQKVNK361rXn0rXkf-95_Zw51otYH5HP7fuo766p1ROPrCwQR-gUmFbg4aOZZ-uL-YnVqDuMVM3R-I6FU',
#   'userName': 'Asooo aaz',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwwugd6rKS9HDA_1UMsxgflsXTHHPDH58PmKFT4=mo',
#   'content': 'This is very important to me application🥰',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 11, 59, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGUqwvsLDvDDE5I3wWvysDIztsGErTZaT-KfYAmvTzqaRv4nx9lFYXXUsGG3sxNBknUxzxRJzG6YpguvVE',
#   'userName': 'Salman By pt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjodhOI7tjYgElsQeBM1t-pzCezI3EvUVbvGKzq',
#   'content': 'Very Nice Good Work In Application 🥰',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 11, 3, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOE3Hn5UIVSNkgkANCC3iO2hIlxP5WAvKtO3us-IPKlXQgmU3JXVrNHA04LJGu6uJs3qjKfFfqibQMYD09Y',
#   'userName': 'Sakinder bukhari Cool',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyHZjFGvkLLAlf9K-yY7fSu0uEoVjbsKL5YIvyk=mo',
#   'content': 'i like it application very good working application 🥰',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 16, 10, 52, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHQMX25wrVh6bj87KgrFHrTFEs6OIwhDlOMkndU47nNSZXszw9fczUPjThBPAbl1O1G75oszb1e8nfAEog',
#   'userName': 'Nusrat Rahat',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxUduI7fWBcUCiG1PjyblDo6r2rL9Dm5hfbHfuy=mo',
#   'content': 'Black Crypto app very good app nice and excellent performance application ###',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 15, 19, 45, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFaD1kh1GpoELw9mCEBrT_O7Sigp5raaryvzPsF02hYDW3FJYHZFpIaLcqMOfp9pwh7B76NYGpmmpVQadc',
#   'userName': 'Ladi Doll',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi46kRZCOtBiLhOaKE2vZuwSFBwrk2d5W2kEXwU',
#   'content': 'Very interesting and up to date and legal mining process in the world of crypto blockchain process.🙂🙂',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 15, 17, 20, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOE6M6zDud03oOO1u5NbhMvniDxAT8OtZiLMi8dmLeSDc8DHvXAQDKNRPIFakZY5FEPC3DCZiWbo-SteoHc',
#   'userName': 'peter gatimu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggul2qG3M3QPe7BU95lpqrDS7FEowBJvywMeYXc',
#   'content': 'Total scam.. Stay away.. Bought a plan that never activated.. I know what am saying.. Stay away. These are 100% thieves',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 15, 14, 51, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFkbM_qpgao46GfyfgbmoIp3jIuMVkB1ZYDo09jA0YRaZInJQoYFFAyEyZK_usU6x0Beo2Kb_65ryf878o',
#   'userName': 'Zara Thequeen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw-3nXwRBqc0oD6BkFBkwoidl26mEDQC1JFyTpv=mo',
#   'content': 'New Bitcoin cloud mining network for easy earning +++',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 15, 7, 36, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFda2L--2uAmBrftHnHmGXatSDk11sRzAaEEJB89bz572Vq5WBvTV6IA6wAibbonvsX-QDqgmCFPwqnZBY',
#   'userName': 'Patrick Richard',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjoGOwN5bHhl5LMVu1g7Q3YNB-og4sk7Qvt-b2X',
#   'content': "Okay so farm only problem is every time I go to the homepage it stops mining and closes out and I lose all the mining coins I've earned and I have to restart all over again it only works when I keep the app up it will not run in the background it would be awesome if you can have the app running the background like the other apps that do mining",
#   'score': 3,
#   'thumbsUpCount': 23,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 15, 4, 18, 45),
#   'replyContent': 'Fisrt of all we does not allow background mining. Now the reason is that it is mendatory to stop mining once you want to change activity . Thats why your balance is not saving and app is crasing once you click on start mininh on second time',
#   'repliedAt': datetime.datetime(2022, 2, 15, 5, 5, 12),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHgRKFeRn4ClfDan9o9rPnQaitoLomyeOXx_EtXAVDo9VnvD-uM1cadDgJ89vEldXU7EugLPa8SIcD8zCw',
#   'userName': 'Thanos Jerry',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzQ29eiMiYziGZhq0ANDc829aOG39cO5ZJCSWLG=mo',
#   'content': 'Nice graphics and simple to use . Easy to instant withdraw',
#   'score': 5,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 14, 22, 49, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEmoHmyM8yQy1wLBTdbGZkgnv7hqNup_oi3Dbxtycu1Iet80Ba6KKXRpT92VPCtWyAEA5oNoyDa87MTh0Y',
#   'userName': 'Katrina Queen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyunBcLkNNKBCKjuKUy0iUSzjgRR0aHIb2ZytiQ=mo',
#   'content': 'Fabulous application . This help me a lot to earn the money .best paltform I recommend to all . Install this application and earn a lot',
#   'score': 5,
#   'thumbsUpCount': 29,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 14, 21, 9, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFyLw9B02t0a9A_55GxV0NFm-aRD47kZ-ZGaRy60NWr9GYaOux4Ra25gUnpmT01bgM-qm_rY1rbYlwXEFM',
#   'userName': 'vashishtha kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiSZ1oBdW18VM94PzNgmayv8ul4dFODnf9ukUt69A',
#   'content': 'Mc###d Devloper...',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.6',
#   'at': datetime.datetime(2022, 2, 14, 20, 58, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGe1Tjqnxo-Mt2pJHXWl-UEGHkV6ocny5UDjj5vDeMT8YRDA2xF3PHibNHDhZiJFbKou1mhM64AcDa4TXw',
#   'userName': 'Sundram pandey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjQ9CIEJwpRBzc_ICWENyCHaJmDxMNwUpOttYaKAg',
#   'content': 'Please move screen up side because main option is not showing',
#   'score': 4,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 14, 12, 18, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFjLAzMdp7Wnx4gJAyhQ_OMrRLXByx3sYFSm_M3fDS731dBi5min0NMQ3UYfkbIF_xZTAa9swXVpROWTJs',
#   'userName': 'Morkl Mili',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzCPtdUinNNg2MloRDvItTV9_jqCgXQbU2cu00b=mo',
#   'content': "You can download this app and increase your crypto coins count and it's awesome. 😍",
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 14, 11, 59, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEEyZRnTMLBU5-GjuA8WX64-8P0nEQaGAwrZpJjYLwYT36eAcICEfmkYkxzwlxG84HsqsLgDJlyV_yj0j4',
#   'userName': 'শহিদুল ইসলাম ছাহিদ',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh-x37-r0NgrrrKAZt84My_K4q64AXQz_1T-SvXTA',
#   'content': "Fake app, don't waste ur time Rubbish 😡😡",
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 14, 11, 33, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHp5FcU4RWu_KYiXpQ767-5RFD1ZA_Aj3CvE4I_JSAWTp1Y84AU1vvXoafIFhFv1LLLz-o0MvBfCPscVd8',
#   'userName': 'Robynn Harbin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjLSTj4pcs045PwJR_vWtk7hL4o0ttQm1sc7DFpjU8',
#   'content': "You should be able to tell it's fake by the five star and four-star reviews. They are all on the same format, most of them mentioned the app by name or mention the Google Play store. They all also have an emoji or two at the end or a symbols.",
#   'score': 1,
#   'thumbsUpCount': 18,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 14, 7, 7, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGO5Ptdl9-KwfUxsdjfJKD_nMoZhTjg9nWNyAhBn6pS6DCWc0-HlGmzaUf4K_AA3HAbfBm7u6iftPINmfU',
#   'userName': 'Christopher Mackenzie',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxprG-9HNZrSgyHkNXIJtJwqIkI2yB0p-ArW2KN=mo',
#   'content': "Fake mining app. Don't bother.",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 14, 4, 9, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHBsRrgOMlmIcMrGE1CTLWtJrvyemKEwtA8HSgBVy1G6tjJyse2YZYiNEu6tZVpG5i3Xx-fHxJWvhpe3GA',
#   'userName': 'Lucars Mandlin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyzllPUlLeSLPHuN4IzxOOFm6uo8wAehYJWvVoS=mo',
#   'content': 'Why will the mine stop after minimizing plz its scam...stay away',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 14, 2, 59, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEexnQaZsPtx2vdBWbw47VHWA1FXpwEuN2EQx-rgWiVoSoktSOhw7xdAFwy8OKYKdsrtcm9GOaQz6myqc8',
#   'userName': 'Sohail Rao',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjdOgwii88MgWUu_ulDnDwhT1eOMT14QRPge_0kzA',
#   'content': "This is good for crypto. It's features are Outstanding and black crypto is easy to mining 😍",
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 13, 23, 22, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEuKfqQKDO93TVf0796IbmJ4rjl-loV94kswhcGNhNb93lLxV3N52UaYJ1vrDOwG6fTIbUURqxIfWqjYUs',
#   'userName': '_ SSG_',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj-mss6tm7lcLBTtRNdZadHCrq3t5xj7rRjhP4YrA',
#   'content': "Useless app all time crash even can't start mining",
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 13, 11, 41, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOGxwUmtMMyjV07VdYlQ53hz4bY6ccOTuwNM1LUcHZ_-4wCOvr5bV3b9cCSLVlPJQz3ldQ8fJE1WXHP8o0I',
#   'userName': 'SHOSONIC SPOT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GguhfBWC0NtyF128FOyu4oQ0kg7lXJkffjayOEK',
#   'content': 'Scam',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 12, 21, 21, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOEQuByFfctzBKy2WtHyUsgfUcFBiPIObkWNTKbsfqwfJmodKlVE3lkVyCS9ER4jMYxdiT_yOP99O9IXHVs',
#   'userName': 'mil beno',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz7GqBroDURBwy-T0deMrAOfly34TKUSKLUij-F=mo',
#   'content': 'scam',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 12, 8, 47, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHQfo20DC2Tltx-m42u4KA8PyNR6oi_XJZva_Vppt6FzgB3Lk_YJ0Ymu03mrB_Cyxm04mDWH4mnDOZ3iKA',
#   'userName': 'gordon cairns',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgNZT3utFpjKduKAcgFrk4vtqAg8z118DY2x1s9uQ',
#   'content': 'Hmm very fishy app 3 mineing bit cion you get 20.00 right away but can ownly use it on 1 mine not all of them and how do I tranfer it to my bit cion wallet',
#   'score': 3,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 12, 8, 13, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOFqV5p-jLcWlBuXyQu4-bYI3FocyXpP-TQtu1NymslgsnPuwCRNejZuZIBHuIZ3NNgJiiqkzh1JQA7S2ec',
#   'userName': 'Jaxon Hollis',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjoCRNjNKiG8n5cKEQ2r3Jat6gwlc1XjMsINDIxaw',
#   'content': 'Stop cryptocurrency!! Save the planet!!',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.5',
#   'at': datetime.datetime(2022, 2, 12, 3, 24),
#   'replyContent': 'How can we help you. You can contact via email . Our team will guide you completely',
#   'repliedAt': datetime.datetime(2022, 2, 12, 3, 27, 10),
#   'app': 'com.black_crypto'},
#  {'reviewId': 'gp:AOqpTOHx1I7YwIxblu3CSgJWeQf5c8MI2RSbSLR_tcVaGpL76nhwVcaTjDkrJCOwELYkWlTipIpQL_snZU2Eah0',
#   'userName': 'Shagufta TSH',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwejJnVLK92rOURl8wvQ04lwBhFfSJpqesWNlt5=mo',
# ...
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 36, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHoQFXfghvb7RdDAOI2f6WREdbKcrQOB6HbwYHux6_HffyhT6w9kLfwe-YEE2ejEFLuzWg6FEEBt5WMLv0',
#   'userName': 'Shawnna Barnett',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzD6vHIjwxw76nrwKlh1FxnBOS6OzYVP1qFFrcM=mo',
#   'content': 'The original is the best!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 33, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHIfmnsfsvBBtZgbi2TEm96CCE0IF69MkJcoXHph-1Hkeg9q-9m-2xaTmqEkrGg8QND7tAltofus6Yrx7g',
#   'userName': 'Emmie',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhHcTrZAqqjrwu-Qh6r7U7oO6-_aqQAmXZEHVKoyg',
#   'content': "Not worth even 1 star. It's so obviously rigged that it's just laughable. I struggled on one level over and over, and as soon as I used some of the gold bars I won from a race, suddenly the game finished the level in the next move. Hmmm, wonder why it suddenly got so easy and beatable in 2 seconds? I don't understand how some people can get to level 3000 or 5000 or whatever. I got to around 500 and got so frustrated at the obvious rigged system and couldn't do it any more.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 3, 32, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGoqjkLC8UOIYWPa5D3DK0XvOU3YoXgGTPPS8prq1aEx1SWzZE6GFFDJzVUKRiqclo2jbdV8y05tRymqXI',
#   'userName': 'ijaz ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwAnGC_m8BPXpfBdA_svAMor24l5Ia_wWeRRywO=mo',
#   'content': 'Good 👍😊😊👍👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 3, 30, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEy3v3hUIS7gWK2ucHSBSoWp2DkCv0Rn04RrNevuRpreD7HUpZueByHW7xsIONxH68RI5vo3ySMNKY7xGY',
#   'userName': 'Martin Pemberton',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyQhoo6AQMQYeu_0nD7tuRHVyfUh24Xgw0xGCvI=mo',
#   'content': "It's the the same as the first few times instatlled it, just fine.",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 29, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGb1qQtfRMd1xBBoBav6L2QTkGKoou1eZu66JkL4HmzMhzTFSjhXXPvxeooklqlWQaP4-91hn1N9TNTkws',
#   'userName': 'Pavithra Anil',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzFFwChppwBnMraAmycVej_iIUCWdYhVb8ROIui=mo',
#   'content': 'Super',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.221.0.4',
#   'at': datetime.datetime(2022, 3, 22, 3, 29, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHK5Xu5OHP80uE5moQkU7WMU5GaOsCyy7wFO2bIeGsXmNkywIMi80kzgdh15sRcXtP6ieAGO0KxBFtl_Nk',
#   'userName': 'XIRAD RAH.চয়ন.',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi4zG-nMrbl1vsXj49xRhjdu0VIotZxSP_7XszykA',
#   'content': 'About what?',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 27, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEL8W8t2UWNQ0sXv0xUnDXk568c9BUcNrvRpQVxaOqnQ6e_Y5dY2BSk63fBIgh8yEJY3EasclatFLTf8o0',
#   'userName': 'Samantha Underwood',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjd7tDwD8Muc19CukIGHEDkeC5gkDbcshfSR43Q',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 24, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOH8LHgB4uLTKdJHeICq7Xpgw-tAaJR92uQhnIu84XDebsmmHRQ2WElWlLSuULwm8kxpphYyyVbaR3DD2rs',
#   'userName': 'Noble Ewah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg0U9iE325pCcGqSeNXp1E5tZbn1DVbck-KZaUWLxw',
#   'content': 'Great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 3, 23, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEcfSyv6LdNlR-kz6rY1Shrtq0ofjzwLPJuTP9dNUUiLR-l66Xs3vlAp2wt9ydRtmLmbzPJ5W9vePyYC3A',
#   'userName': 'Ronewa Mphephu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzhqbv2YnKe3fU0NAXx1ocwGguJgvvaemJYJAuH=mo',
#   'content': 'So good...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 21, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGOAgDjodkQen8g_WM7DIyVTv9rZ3aDO2q2mQkGDdIKS2DTxH5AHT4KBCNKN3OPceo43dwDl2l4bu9fJq8',
#   'userName': 'steve kjarmo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwP4hZcSCFo-xNJxQewOVOjiBjwIHrCjaAyERMc=mo',
#   'content': "This review sinks me. Gm is meant to get you to bite on extras. I'm sure my playing today is done. I will have to wait till they decide I pass a level",
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 20, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOFjunEW6wRYgJXpjNooNlcJHpdLw9jnNNpJDhCe2iOWRZGmrixUIZ1XuQ9qddQYHtD6Rm0FvKnftx_AHqw',
#   'userName': 'Rama Jj',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz4SG6HZ6Vmic42snyR0TZpqwyTSqhKvIPTay97=mo',
#   'content': 'This is the amazing game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.221.0.4',
#   'at': datetime.datetime(2022, 3, 22, 3, 18, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHEYoYJzRy597uT7EEZw5llIblOEknxt3IyM6AvP8fETvMQ6I4_8olNldR44RKGfkv-LwsP5c-SgwwWVjc',
#   'userName': 'Marc Ferreira',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzB-XSGOHpEgQTX716OiKMtTi8LSGa5lPDUGc6o=mo',
#   'content': 'Awesome!!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 16, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOE1RFyw5w5MMK83pJAFlq2-i6jI11ZUzb1j6qqHsgc9em2M-xZITwIfoGSZw9s4OcQYwCoIvtFP1KwputU',
#   'userName': 'Libier Corrales',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzz4o7tWj0RFmlgZMYf74p4nnm6vMDtCE-dgxim=mo',
#   'content': '0 0.m .',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 16, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGEK6_1v9EMz7iLI4ZBW_p2SD0iHlcG3u_SMhs08ZORhNRg2qZIPiPp32laBCnVOcu1fN9ERQTSp4qmgpk',
#   'userName': 'Shenella Luke',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwDUS7CECG-lC4nemCkDrNSxPcUsiijt9FDYMcI=mo',
#   'content': 'Its tons of fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 14, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOFoA1N2WeRY87XalF6Ua5TVUDgDXFccpfXFWTaGZYuK226BZ-UKhK4DFnkPCQyrFmYHqDSkPmAVnOlRfT8',
#   'userName': 'Regene Renee Baehr',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhZRNDTEEdhhU2Qlej9-XW_-CSlm7VVMeVE_gQ',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 3, 12, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEMcI9HQXa-aPIKDkv2NmQ4qWm-7r-JT90JfVRxpXSDNbihqyCzHLRjpZxLCNOMqTYNLzjBf9urSrAXlYM',
#   'userName': 'Nightmare Redlue',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjmFnrNsfJlzVWcPQJAvuzgl6gdrf6zMQQ0S4Pf',
#   'content': 'Good game can be challenging but its fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 8, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOE7SsI1jzaI56u3V6ZlPBbMWpuJReUCFfNsTvLGh46XRKAt4xnDB4u1EaQ-bXdeFg_fBfo3jdz4-u9B12I',
#   'userName': 'Julie Chanttella',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyiAkDKPY3WFkGCcWD4uYaurEkGEDjIsCtAXkZG=mo',
#   'content': "It's time entertaining 🥰🥰",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 4, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOFSROl4cBYGvGIlV9rUBp0FqcCgB53rSGLvXWpHFUZjw63JBX3FQIRUsgwqd3UgVfEOtlz7wUMarmHRInY',
#   'userName': 'tenesha white',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwu2vh2ODHQW2QsvqfOo2KNL5AnNOJx29iCyGGy=mo',
#   'content': '😁',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 3, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHEH16McXpHajxnhRvvohUOvDH0_hDh_CFH4AzJbjrSwtQGysuaVpgWd78I4zJCeeTL6KSfsSKPcaU9pG0',
#   'userName': 'David Stewart',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJygpEh371J-8OwD1o5r46jT1j4pm1aF-wlOS21r=mo',
#   'content': 'Some levels are very challenging, hard to earn gold bars too that extent play.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 3, 2, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOELHk4zfZ5VoXhNAzhchJiyqc_VwUjQP3H8Z5nrBW5D_ixssyrlg1CaXPYr3fRu8Cs9p3s8hDRG0Up6_ZM',
#   'userName': 'Michael Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgTX733rSSzyGrBCSNDnzIBv1rh0yoSRDgs2Hh5mg',
#   'content': "I had gota number phone it's starting me back over",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 3, 0, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOH6-F_d9qcvimMOcx080iPm5dHD6PY5tttQmyjG2XcZIz2zR_greyUbXC7SQhFl00ea4UKR0_Lv9guNais',
#   'userName': 'Laura Big Canoe',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzCREy0xgTHHxJfpipYU4olQcRlYgVPiOAkHt6P=mo',
#   'content': 'Fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.215.0.1',
#   'at': datetime.datetime(2022, 3, 22, 2, 58, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOFf0PGzzedvDGeAXmJ6qFlpm5a1GmQk1r2QhsdsChlEDC33rS974k8LDZfqPt2Qnuk1pdrrxVp6gMoY0GU',
#   'userName': 'Lwindhi Gomz',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwonDej_Pv1snAD8bxH7CoOYFyVA1mrTz31RbTD=mo',
#   'content': "It's very fun",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.219.0.6',
#   'at': datetime.datetime(2022, 3, 22, 2, 58, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEGHgztngV2nDHBY7-tUwUn89W88tIZx_VVEyuX5VfQDS7O9lK8b24nn9SHdukFn7CGaqBn4V-2cdCLFFA',
#   'userName': 'Geff Ludwick',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyY__NSfLnWtcw3eFwRcZQNaIHh84HStK9FAOyO=mo',
#   'content': 'Addicting',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 56, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOEm4Ah_xjRUW_wbIBzm4JF4_nbdyOsCK32l5lPwElgeE6zQnv_Bho0KySc3q_LgT9pw6PL9cIPF_IZVWtk',
#   'userName': 'Dimakatso Precious',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyGRE7fs1AtJcqpn2zxAVVoLipfkiiNDetAxNvL=mo',
#   'content': "Release stress, it's addictive and enjoyable",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.223.1.1',
#   'at': datetime.datetime(2022, 3, 22, 2, 55, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHJLHYJakJTAPzh-FqWpWle3z-AyBGwx498U01p5Xpg3n6lpWtnUjMhqPxX0UxsA-DNl8qaG8NTE6FUcTM',
#   'userName': 'Matthew Silkett',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiXB7oXw1ApUnkspStZG1WBwe9PkkHrAMbsaj3eYQ',
#   'content': ',😁',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 3, 22, 2, 54, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGE99Jtq9pFwBDh4gdsMbXaUxntNOH1Zed5w8xJ8jcbYHPyjyctYXpvOztEMRPHQzl9lwBGnCDDOMm9UDE',
#   'userName': 'Sharon Booe',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhENyJ2oS1tUSP072XpQ046OII0QHg_PhuFQ_guag',
#   'content': "Your company just took 4.22 from my account and didn't give me anything. Put my money back or fix this please.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 54, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGRt9vGCDkCBd09mOizNNZWqFBQ7ZXSZv0b6ZScAiU7hqv-iqaM0HTvK2F27wPL3BGj4aj5amw4PmXwPNs',
#   'userName': 'chirag bariya',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxCvGG4K5YMHY6zSI-KmiELJxBPhFDefaPfgxSVeQ=mo',
#   'content': 'good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 53, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGqAhhF_paNZM_TROHWOHAhlOAFhRP3NhFWpuVUmE5LcoHUFyJ_sdBQjAB8z7MYoOTGyAYX7A5SBTP4wW8',
#   'userName': 'WAN AFIQ',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhnIooxIRozMMlsvkv4xTb-TGXfQn3DZzUYsvKtLg',
#   'content': 'fun and relaxing game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 52, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOHOZJnT6YCNOF7asDdXv_SkCTozl7jIeT9TP3RW75jFoEBhc3RWmyH83U_kOJLWMjU07GDYGU-1QY2mZpM',
#   'userName': 'Rahul informations',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhxrV5GlBjPUpIpD-J7JlnvvEzfAvKAlCd5O08b0w',
#   'content': 'Great app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 51, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOGUBKOmtWEtK8iruw--zUM0ciJO6RxqNYzHl9DNmBKrS7hZ5VLZh1cVb1rPJbMbZPolDDb_8IlGMZvnSd4',
#   'userName': 'Richy El Zurdo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgW7TNNUR9PDCM0roqLcPTFV302xCw26_U5h_Qe',
#   'content': 'Fantastic!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 49, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  {'reviewId': 'gp:AOqpTOFg7eCD1M_N_CeGcXfW_o3EKYfV8Q3iyT4gvCCYi6ZJqjgOUgDSCHh11aqbjc9r5xJzPQEsmRJG7kGzAVA',
#   'userName': 'tina seddon-parker',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJy9HEEUeelzEi34iZWLoUiA6BxdNuUrpejAqtfN=mo',
#   'content': 'Sweet games',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.222.0.2',
#   'at': datetime.datetime(2022, 3, 22, 2, 46, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'app': 'com.king.candycrushsaga'},
#  ...]

# %%
df.groupby('app').count()
# Out:
#                                    reviewId  userName  userImage  content  \
# app
# com.activision.callofduty.shooter      1000      1000       1000     1000
# com.adobe.lrmobile                     1000      1000       1000     1000
# com.black_crypto                        344       344        344      344
# com.dts.freefireth                     1000      1000       1000     1000
# com.facebook.katana                    1000      1000       1000     1000
# com.flipkart.android                   1000      1000       1000     1000
# com.instagram.android                  1000      1000       1000     1000
# com.kiloo.subwaysurf                   1000      1000       1000     1000
# com.king.candycrushsaga                1000      1000       1000     1000
# com.ludo.king                          1000      1000       1000     1000
# com.miniclip.eightballpool             1000      1000       1000     1000
# com.mxtech.videoplayer.ad              1000      1000       1000     1000
# com.phonepe.app                        1000      1000       1000     1000
# com.pubg.imobile                       1000      1000       1000     1000
# com.snapchat.android                   1000      1000       1000     1000
# com.supercell.clashofclans             1000      1000       1000     1000
# com.truecaller                         1000      1000       1000     1000
# com.whatsapp                           1000      1000       1000     1000
# net.one97.paytm                        1000      1000       1000     1000
# org.telegram.messenger                 1000      1000       1000      999
#
#                                    score  thumbsUpCount  reviewCreatedVersion  \
# app
# com.activision.callofduty.shooter   1000           1000                   541
# com.adobe.lrmobile                  1000           1000                   387
# com.black_crypto                     344            344                    54
# com.dts.freefireth                  1000           1000                   524
# com.facebook.katana                 1000           1000                   723
# com.flipkart.android                1000           1000                   830
# com.instagram.android               1000           1000                   720
# com.kiloo.subwaysurf                1000           1000                   533
# com.king.candycrushsaga             1000           1000                   832
# com.ludo.king                       1000           1000                   437
# com.miniclip.eightballpool          1000           1000                   771
# com.mxtech.videoplayer.ad           1000           1000                   780
# com.phonepe.app                     1000           1000                   822
# com.pubg.imobile                    1000           1000                   771
# com.snapchat.android                1000           1000                   493
# com.supercell.clashofclans          1000           1000                   693
# com.truecaller                      1000           1000                   787
# com.whatsapp                        1000           1000                   802
# net.one97.paytm                     1000           1000                   855
# org.telegram.messenger              1000           1000                   696
#
#                                      at  replyContent  repliedAt
# app
# com.activision.callofduty.shooter  1000             0          0
# com.adobe.lrmobile                 1000            63         63
# com.black_crypto                    344             7          7
# com.dts.freefireth                 1000             2          2
# com.facebook.katana                1000             0          0
# com.flipkart.android               1000             5          5
# com.instagram.android              1000             0          0
# com.kiloo.subwaysurf               1000           114        114
# com.king.candycrushsaga            1000             0          0
# com.ludo.king                      1000            44         44
# com.miniclip.eightballpool         1000             8          8
# com.mxtech.videoplayer.ad          1000           294        294
# com.phonepe.app                    1000           151        151
# com.pubg.imobile                   1000            13         13
# com.snapchat.android               1000             0          0
# com.supercell.clashofclans         1000             0          0
# com.truecaller                     1000            11         11
# com.whatsapp                       1000             0          0
# net.one97.paytm                    1000           485        485
# org.telegram.messenger             1000             4          4

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///db.sqlite3',)

# %%
from textblob import TextBlob

# %%
df.columns.tolist()
# Out:
# ['reviewId',
#  'userName',
#  'userImage',
#  'content',
#  'score',
#  'thumbsUpCount',
#  'reviewCreatedVersion',
#  'at',
#  'replyContent',
#  'repliedAt',
#  'app']

# %%
def sentiment_analysis(review):
  def getSubjectivity(text):
    try:
      return TextBlob(text).sentiment.subjectivity
    except:
      return None
  
  #Create a function to get the polarity
  def getPolarity(text):
    try:
      return TextBlob(text).sentiment.polarity
    except:
      return None

  def getAnalysis(score):
    if isinstance(score,(int,float)):
      if score < - 0.5:
        return 'Very Negative'
      elif score >= -0.5 and score < 0:
        return "Negative"
      elif score == 0:
        return 'Neutral'
      elif score > 0 and score <=0.5:
        return 'Positive'
      else:
        return 'Very Positive'
  
  #Create two new columns ‘Subjectivity’ & ‘Polarity’
  try:
    review['subjectivity'] =   review['content'].apply(getSubjectivity)
    review ['polarity'] = review['content'].apply(getPolarity)
    review ['analysis'] = review['polarity'].apply(getAnalysis)
  except Exception as e:
    print(e)
  return review

# %%
result = sentiment_analysis(df)

# %%
result.head(2)
# Out:
#                                             reviewId       userName  \
# 0  gp:AOqpTOFKkjuer-OMthMDUrXGNqzCpIPT9ko1xuuhqDD...  Humpty Qadeer
# 1  gp:AOqpTOHIYckh1-I8jbATi2WAiVZBsUFGeqUQW7vmOwV...     Danish Ali
#
#                                            userImage              content  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...        Awesome app $
# 1  https://play-lh.googleusercontent.com/a/AATXAJ...  This is a good app+
#
#    score  thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0      5              0                 None 2022-03-22 17:17:03         None
# 1      5              0                 None 2022-03-22 16:43:20         None
#
#   repliedAt               app  subjectivity  polarity       analysis
# 0       NaT  com.black_crypto           1.0       1.0  Very Positive
# 1       NaT  com.black_crypto           0.6       0.7  Very Positive

# %%
result.columns.tolist()
# Out:
# ['reviewId',
#  'userName',
#  'userImage',
#  'content',
#  'score',
#  'thumbsUpCount',
#  'reviewCreatedVersion',
#  'at',
#  'replyContent',
#  'repliedAt',
#  'app',
#  'subjectivity',
#  'polarity',
#  'analysis']

# %%
result[['app','polarity','analysis','subjectivity','score','content']]
# Out:
#                               app  polarity       analysis  subjectivity  \
# 0                com.black_crypto  1.000000  Very Positive      1.000000
# 1                com.black_crypto  0.700000  Very Positive      0.600000
# 2                com.black_crypto  0.377778       Positive      0.444444
# 3                com.black_crypto  0.583333  Very Positive      0.783333
# 4                com.black_crypto  0.400000       Positive      1.000000
# ...                           ...       ...            ...           ...
# 19339  com.miniclip.eightballpool  0.625000  Very Positive      0.500000
# 19340  com.miniclip.eightballpool  0.150000       Positive      0.500000
# 19341  com.miniclip.eightballpool -0.001786       Negative      0.222619
# 19342  com.miniclip.eightballpool  0.050000       Positive      0.575000
# 19343  com.miniclip.eightballpool -0.400000       Negative      0.400000
#
#        score                                            content
# 0          5                                      Awesome app $
# 1          5                                This is a good app+
# 2          5  Black Crypto is real good and useful this appl...
# 3          5  Black crypto cloud mining app is awesome reall...
# 4          5  Fabulous application .This help me a lotto ear...
# ...      ...                                                ...
# 19339      5                          Awsome better than coffe!
# 19340      5                                          Good game
# 19341      1  constant closing for no apparent reason in the...
# 19342      5                                        Lovely game
# 19343      5                                         beest game
#
# [19344 rows x 6 columns]

# %%
pool = result['app'] == 'com.miniclip.eightballpool'
pool_result = result[pool].copy()

# %%
pool_result
# Out:
#                                                 reviewId            userName  \
# 18344  gp:AOqpTOFTo2EgdeePbCAhh4QL7Jm3iF0SSAXsRsQ5t9K...  Azmathulla Shariff
# 18345  gp:AOqpTOGk8tlaPHXJyLWw8QAwgDdnZef2RRwUTJYBZH6...            mp kumar
# 18346  gp:AOqpTOEbLoXXRfoPUTX064vQ0luboUYMJRvN1g41nzX...       Affaq Hussain
# 18347  gp:AOqpTOGup4OefuBK9lbJB6PEpIJ-I66g3soAj8ah_pk...  faisal chhavniwala
# 18348  gp:AOqpTOEZ7SotNPttP7iZ3QGbQ-GY8An5K_36wphTTnk...           EMINEM 28
# ...                                                  ...                 ...
# 19339  gp:AOqpTOFKChLb4UFq-Pn3DZ5ScetFQxjemjIB2QTBMK5...    Curtis Patterson
# 19340  gp:AOqpTOEnhAOwKBXW6DcAIcCe6-sonpOZqTXsEpsiNJ0...      Huzaifa Mughal
# 19341  gp:AOqpTOH4OgobTHlcviJphmEU2ulblse_B4ljdTT-Og-...          Wes Greene
# 19342  gp:AOqpTOGEanQpPWkuzlL1lIYjwPDNIxUzSd94BXSdxSN...       Tochi Onuigbo
# 19343  gp:AOqpTOGQ4Tzc2svk0f4eE9fuMUVgncVypKJAsEUOUKS...    Sardar Moqawomad
#
#                                                userImage  \
# 18344  https://play-lh.googleusercontent.com/a/AATXAJ...
# 18345  https://play-lh.googleusercontent.com/a-/AOh14...
# 18346  https://play-lh.googleusercontent.com/a/AATXAJ...
# 18347  https://play-lh.googleusercontent.com/a/AATXAJ...
# 18348  https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                  ...
# 19339  https://play-lh.googleusercontent.com/a-/AOh14...
# 19340  https://play-lh.googleusercontent.com/a/AATXAJ...
# 19341  https://play-lh.googleusercontent.com/a/AATXAJ...
# 19342  https://play-lh.googleusercontent.com/a/AATXAJ...
# 19343  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                  content  score  \
# 18344             game Is good and vary unless game good      5
# 18345                                    Most worst game      1
# 18346                                       Ads are more      5
# 18347                                          nice game      5
# 18348                                              Ftuui      1
# ...                                                  ...    ...
# 19339                          Awsome better than coffe!      5
# 19340                                          Good game      5
# 19341  constant closing for no apparent reason in the...      1
# 19342                                        Lovely game      5
# 19343                                         beest game      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 18344              0                5.7.0 2022-03-22 18:24:15         None
# 18345              0                5.7.0 2022-03-22 18:23:45         None
# 18346              0                5.6.7 2022-03-22 18:22:12         None
# 18347              0                5.7.0 2022-03-22 18:21:07         None
# 18348              0                 None 2022-03-22 18:19:43         None
# ...              ...                  ...                 ...          ...
# 19339              0                5.4.5 2022-03-21 10:48:36         None
# 19340              0                 None 2022-03-21 10:46:34         None
# 19341              0                5.7.0 2022-03-21 10:46:28         None
# 19342              0                5.7.0 2022-03-21 10:39:57         None
# 19343              0                5.7.0 2022-03-21 10:37:39         None
#
#       repliedAt                         app  subjectivity  polarity  \
# 18344       NaT  com.miniclip.eightballpool      0.500000  0.150000
# 18345       NaT  com.miniclip.eightballpool      0.633333 -0.300000
# 18346       NaT  com.miniclip.eightballpool      0.500000  0.500000
# 18347       NaT  com.miniclip.eightballpool      0.700000  0.100000
# 18348       NaT  com.miniclip.eightballpool      0.000000  0.000000
# ...         ...                         ...           ...       ...
# 19339       NaT  com.miniclip.eightballpool      0.500000  0.625000
# 19340       NaT  com.miniclip.eightballpool      0.500000  0.150000
# 19341       NaT  com.miniclip.eightballpool      0.222619 -0.001786
# 19342       NaT  com.miniclip.eightballpool      0.575000  0.050000
# 19343       NaT  com.miniclip.eightballpool      0.400000 -0.400000
#
#             analysis
# 18344       Positive
# 18345       Negative
# 18346       Positive
# 18347       Positive
# 18348        Neutral
# ...              ...
# 19339  Very Positive
# 19340       Positive
# 19341       Negative
# 19342       Positive
# 19343       Negative
#
# [1000 rows x 14 columns]

# %%
df.to_sql("reviews",engine,if_exists='replace',index=None)

# %%
result['analysis'].value_counts()
# Out:
# Very Positive    6197
# Neutral          5846
# Positive         5117
# Negative         1758
# Very Negative     426
# Name: analysis, dtype: int64

# %%
result['analysis'].value_counts()[:20].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='analysis'>
